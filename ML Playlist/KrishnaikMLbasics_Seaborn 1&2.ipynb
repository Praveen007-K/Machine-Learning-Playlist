# %%
import seaborn as sb

# %%
sb.get_dataset_names()
# Out:
# D:\Softwares\anaconda\lib\site-packages\seaborn\utils.py:384: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 384 of the file D:\Softwares\anaconda\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
df=sb.load_dataset("tips")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#corelation with heatmap

# %%
df.corr()#only int and float (heatmap) Pearson corelation
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sb.heatmap(df.corr())

# %%
#Join Plot-2 num features.Bivariate Analysis

# %%
sb.jointplot(x='tip',y='total_bill',data=df,kind='hex')

# %%
sb.jointplot(x='tip',y='total_bill',data=df,kind='reg')

# %%
#Pair plot

# %%
sb.pairplot(df)

# %%
sb.pairplot(df,hue='sex')

# %%
#Dist plot -distribution of columns

# %%
sb.distplot(df['tip'])

# %%
sb.distplot(df['tip'],kde=False,bins=10)

# %%
# CATEGORICAL PLOTS

# %%
# Count plot
sb.countplot('sex',data=df)

# %%
sb.countplot(y='sex',data=df)

# %%
sb.countplot('day',data=df)

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sb.barplot(x='total_bill',y='sex',data=df)

# %%
sb.boxplot(x='total_bill',y='day',hue='sex',data=df,color='red')

# %%
sb.violinplot(x='total_bill',y='day',data=df,palette='rainbow')

# %%
#IRIS DATA-HW
