# %%
import pandas as pd

# %%
data = pd.read_excel("containment.xlsx")

# %%
data.head(20)
# Out:
#    Kerala State Disaster Management Authority (KSDMA) Unnamed: 1  \
# 0   Observatory Hills, Vikas Bhavan P.O,Thiruvanan...        NaN
# 1   Day time phone - 0471 2331345, 0471-2331645, N...        NaN
# 2   Toll Free 1079, Fax - 0471 2364424. www.sdma.k...        NaN
# 3   List of Local Self Governments needing special...        NaN
# 4            GO (Ms) No. 18/2020/DMD dated 17-06-2020        NaN
# 5                                              Sl. No   District
# 6                                                 NaN        NaN
# 7                                                   1  Ernakulam
# 8                                                 NaN        NaN
# 9                                                   2  Ernakulam
# 10                                                NaN        NaN
# 11                                                  3  Ernakulam
# 12                                                  4  Ernakulam
# ...
